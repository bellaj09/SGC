# %%
import h5py
import pandas as pd

# %%
f = h5py.File('ohsumed_biobert-base-embeddings.h5', 'r')

# %%
len(f)
# Out:
# 11413

# %%
f_vocab = open('ohsumed_vocab.txt', 'r')

# %%
df = pd.DataFrame(columns = ['token', 'embedding'])
df.head()
# Out:
# Empty DataFrame
# Columns: [token, embedding]
# Index: []

# %%
for i, input in enumerate(f_vocab):
    token = input.strip()
    embedding = f[token]['embedding'][:]

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [token, embedding]
# Index: []

# %%
f['patient']['embedding'][:]
# Out:
# array([ 6.12478554e-02, -2.76048809e-01, -9.31229889e-02, -1.10587500e-01,
#        -2.02945530e-01, -6.36167601e-02,  8.94764066e-02,  3.11486691e-01,
#        -2.25713715e-01,  3.87088358e-02,  1.87432289e-01,  3.51426959e-01,
#        -5.61290920e-01,  3.06944340e-01, -8.38922799e-01,  4.91212487e-01,
#        -1.64258286e-01,  4.01524037e-01,  3.00786018e-01,  1.64108053e-01,
#        -2.29252815e-01, -9.98171747e-01,  1.84266120e-02, -2.43926644e-01,
#        -2.56809175e-01,  3.01688731e-01,  4.72690910e-01,  2.08851263e-01,
#        -3.60292405e-01,  3.18284631e-01,  1.47748336e-01,  4.37263548e-01,
#         2.90670786e-02,  2.47524176e-02, -2.20431969e-01,  3.66406769e-01,
#        -9.67184305e-02, -4.90409955e-02, -3.24926913e-01,  1.67540669e-01,
#         1.56159371e-01, -9.49647725e-02,  3.61953676e-01, -4.06700581e-01,
#        -5.30696452e-01, -4.61954683e-01, -1.96416885e-01,  1.02148630e-01,
# ...

# %%
content = f_vocab.readlines()

# %%
content
# Out:
# []
