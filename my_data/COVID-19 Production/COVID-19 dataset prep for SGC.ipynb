# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv('covid_abstracts_only.csv')
df.head()
# Out:
#            id                                      subject_areas  \
# 0  2005.13653           ('Biomolecules', 'Quantitative Methods')
# 1  2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2  2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3  2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 4  2005.13466  ('Social and Information Networks', 'Cryptogra...
#
#                                                title  \
# 0  unveiling the molecular mechanism of sars-cov-...
# 1  emotion-robust eeg classification for motor im...
# 2  estimates of the proportion of sars-cov-2 infe...
# 3  a mathematical epidemic model using genetic fi...
# 4  on the detection of disinformation campaign ac...
#
#                                             abstract
# 0  Currently, there is no effective antiviral dru...
# 1  Developments in Brain Computer Interfaces (BCI...
# 2  In this paper a Bayesian SEIR model is studied...
# 3  A compartmental epidemic model based on geneti...
# 4  Online manipulation of information has become ...

# %%
df_nonull=df.dropna(subset=['abstract','subject_areas'])
df_nonull.reset_index()
df_nonull
# Out:
#                 id                                      subject_areas  \
# 0       2005.13653           ('Biomolecules', 'Quantitative Methods')
# 1       2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2       2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3       2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 4       2005.13466  ('Social and Information Networks', 'Cryptogra...
# ...            ...                                                ...
# 40379  85066470790  ('Microbiology', 'Immunology', 'Insect Science...
# 40380  85065035348                                ('Drug Discovery',)
# 40381  85073540376  ('Parasitology', 'Microbiology', 'Immunology',...
# 40382  85070056122  ('Microbiology', 'Immunology', 'Insect Science...
# 40383  85064407127         ('Microbiology', 'Microbiology (medical)')
#
#                                                    title  \
# 0      unveiling the molecular mechanism of sars-cov-...
# 1      emotion-robust eeg classification for motor im...
# 2      estimates of the proportion of sars-cov-2 infe...
# 3      a mathematical epidemic model using genetic fi...
# 4      on the detection of disinformation campaign ac...
# ...                                                  ...
# 40379  arterivirus nsp4 antagonizes interferon beta p...
# 40380  architectures and mechanical properties of dru...
# 40381  respiratory syncytial virus nonstructural prot...
# 40382  porcine reproductive and respiratory syndrome ...
# 40383  ifitm genes, variants, and their roles in the ...
#
#                                                 abstract
# 0      Currently, there is no effective antiviral dru...
# 1      Developments in Brain Computer Interfaces (BCI...
# 2      In this paper a Bayesian SEIR model is studied...
# 3      A compartmental epidemic model based on geneti...
# 4      Online manipulation of information has become ...
# ...                                                  ...
# 40379  © 2019 American Society for Microbiology. All...
# 40380  © 2019 Bentham Science Publishers.Background:...
# 40381  © 2019 Sedeyn et al. This is an open access a...
# 40382  Copyright © 2019 American Society for Microbi...
# 40383  © 2019 Zhao, Li, Winkler, An and Guo.Interfer...
#
# [13906 rows x 4 columns]

# %%
len(df_nonull)
# Out:
# 13906

# %% [markdown]
# Steps:
# 1. Determine top 30 most commonly occurring subject labels, and filter down so they aren't redundant.
# 2. Filter dataframe to papers that only contain at least one of these subject labels.
# 3. Reduce each item to one label - pick the most common label for each paper.

# %% [markdown]
# ## Identifying top 30 subject labels

# %%
subjects = df_nonull['subject_areas']
subjects = pd.DataFrame(subjects)
subjects.head()
# Out:
#                                        subject_areas
# 0           ('Biomolecules', 'Quantitative Methods')
# 1  ('Signal Processing', 'Human-Computer Interact...
# 2  ('Populations and Evolution', 'Physics and Soc...
# 3  ('Populations and Evolution', 'Quantitative Me...
# 4  ('Social and Information Networks', 'Cryptogra...

# %%
subjects = pd.concat([subjects, subjects['subject_areas'].str.split("', '", expand=True)], axis=1)
subjects.head()
# Out:
#                                        subject_areas  \
# 0           ('Biomolecules', 'Quantitative Methods')
# 1  ('Signal Processing', 'Human-Computer Interact...
# 2  ('Populations and Evolution', 'Physics and Soc...
# 3  ('Populations and Evolution', 'Quantitative Me...
# 4  ('Social and Information Networks', 'Cryptogra...
#
#                                    0                            1  \
# 0                     ('Biomolecules       Quantitative Methods')
# 1                ('Signal Processing   Human-Computer Interaction
# 2        ('Populations and Evolution        Physics and Society')
# 3        ('Populations and Evolution       Quantitative Methods')
# 4  ('Social and Information Networks  Cryptography and Security')
#
#                   2                   3     4     5     6     7
# 0              None                None  None  None  None  None
# 1  Machine Learning  Machine Learning')  None  None  None  None
# 2              None                None  None  None  None  None
# 3              None                None  None  None  None  None
# 4              None                None  None  None  None  None

# %%
# Loop through and remove special characters
for i in range(8): 
    subjects[i] = subjects[i].str.replace('(','')
    subjects[i] = subjects[i].str.replace(')','')
    subjects[i] = subjects[i].str.replace("'",'')
    subjects[i] = subjects[i].str.replace(",",'')
subjects.head()
# Out:
#                                        subject_areas  \
# 0           ('Biomolecules', 'Quantitative Methods')
# 1  ('Signal Processing', 'Human-Computer Interact...
# 2  ('Populations and Evolution', 'Physics and Soc...
# 3  ('Populations and Evolution', 'Quantitative Me...
# 4  ('Social and Information Networks', 'Cryptogra...
#
#                                  0                           1  \
# 0                     Biomolecules        Quantitative Methods
# 1                Signal Processing  Human-Computer Interaction
# 2        Populations and Evolution         Physics and Society
# 3        Populations and Evolution        Quantitative Methods
# 4  Social and Information Networks   Cryptography and Security
#
#                   2                 3     4     5     6     7
# 0              None              None  None  None  None  None
# 1  Machine Learning  Machine Learning  None  None  None  None
# 2              None              None  None  None  None  None
# 3              None              None  None  None  None  None
# 4              None              None  None  None  None  None

# %%
unique_subjects = pd.unique(subjects.values.ravel('K'))

# %%
len(unique_subjects)
# Out:
# 500

# %%
subjects['subjects_list'] = subjects[subjects.columns[:]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1)

# %%
subjects.head()
# Out:
#                                  0                           1  \
# 0                     Biomolecules        Quantitative Methods
# 1                Signal Processing  Human-Computer Interaction
# 2        Populations and Evolution         Physics and Society
# 3        Populations and Evolution        Quantitative Methods
# 4  Social and Information Networks   Cryptography and Security
#
#                   2                 3     4     5     6     7  \
# 0              None              None  None  None  None  None
# 1  Machine Learning  Machine Learning  None  None  None  None
# 2              None              None  None  None  None  None
# 3              None              None  None  None  None  None
# 4              None              None  None  None  None  None
#
#                                        subjects_list
# 0                  Biomolecules Quantitative Methods
# 1  Signal Processing Human-Computer Interaction M...
# 2      Populations and Evolution Physics and Society
# 3     Populations and Evolution Quantitative Methods
# 4  Social and Information Networks Cryptography a...

# %%
sep_subjects = subjects.iloc[:,0:8]
print(sep_subjects.shape)
sep_subjects.tail()
# Out:
# (13906, 8)
#                     0                     1               2  \
# 40379    Microbiology            Immunology  Insect Science
# 40380  Drug Discovery                  None            None
# 40381    Parasitology          Microbiology      Immunology
# 40382    Microbiology            Immunology  Insect Science
# 40383    Microbiology  Microbiology medical            None
#
#                        3         4         5     6     7
# 40379           Virology      None      None  None  None
# 40380               None      None      None  None  None
# 40381  Molecular Biology  Genetics  Virology  None  None
# 40382           Virology      None      None  None  None
# 40383               None      None      None  None  None

# %% [markdown]
# Subject_count shows how many times each subject is listed for a paper. (Including when papers have multiple labels)

# %%
for i in range(len(unique_subjects)):
    if isinstance(unique_subjects[i], str) == False:
        print(i,unique_subjects[i] )
# Out:
# 413 None

# %%
# Removing 413 because None
unique_subjects = np.delete(unique_subjects,413,0)
len(unique_subjects)
#unique_subjects = unique_subjects.delete([404])
#del unique_subjects[404]
# Out:
# 499

# %%
subject_count = pd.DataFrame(columns=['subject','count'])
subject_count['subject'] = unique_subjects
subject_count.head()
# Out:
#                            subject count
# 0                     Biomolecules   NaN
# 1                Signal Processing   NaN
# 2        Populations and Evolution   NaN
# 3  Social and Information Networks   NaN
# 4         Computation and Language   NaN

# %% [markdown]
# Remove all the redundant/duplicate terms in the top 30 -"Medicine all",

# %%
# DONE: removed Medicine all, 78
# subject_count.loc[subject_count['subject']=="Medicine all"] -> 78
subject_count = subject_count.drop(78,0)
subject_count = subject_count.reset_index(drop=True)
subject_count
# Out:
#                              subject count
# 0                       Biomolecules   NaN
# 1                  Signal Processing   NaN
# 2          Populations and Evolution   NaN
# 3    Social and Information Networks   NaN
# 4           Computation and Language   NaN
# ..                               ...   ...
# 493         Control and Optimization   NaN
# 494       Chemical Health and Safety   NaN
# 495    Colloid and Surface Chemistry   NaN
# 496                      LPN and LVN   NaN
# 497      Space and Planetary Science   NaN
#
# [498 rows x 2 columns]

# %%
subject_count['count']=""
for i in range(len(subject_count)):
    current_subject = subject_count['subject'][i]
    subject_count['count'][i] = subjects.subjects_list.str.count(current_subject).sum()

# %%
subject_count = subject_count.sort_values(by=['count'],ascending=False)
subject_count = subject_count.reset_index(drop=True)
subject_count.head()
# Out:
#                                              subject count
# 0                                Infectious Diseases  1867
# 1                                       Microbiology  1462
# 2                                         Immunology  1201
# 3                                           Virology   930
# 4  Public Health Environmental and Occupational H...   909

# %%
# new column in subjects, indicating if at least one of the top 30 is in the row
#sep_subjects['single_label']=""

# loop through each row.
for index,rows in sep_subjects.iterrows(): 
    #print(index)
    # check each subject from common to least common
    for i in subject_count['subject']: 
         # if the subject is found, set it to be the chosen label, then exit the for loop. otherwise continue searching.
        if np.sum(sep_subjects.loc[index,:].values == i) > 0: 
            sep_subjects.loc[index,'single_label'] = i
            break

# %%
# THIS IS A TESTING CELL 
print(len(sep_subjects[sep_subjects['single_label']==""]), "blank label rows removed")
print(13906-len(sep_subjects[sep_subjects['single_label']==""]), "remaining rows")
#sep_subjects.head()
#print(len(sep_subjects))
# Out:
# 0 blank label rows removed
# 13906 remaining rows

# %%
sep_subjects['single_label'].value_counts().head()
# Out:
# Infectious Diseases                                    1866
# Public Health Environmental and Occupational Health     639
# Surgery                                                 568
# Psychiatry and Mental Health                            375
# Radiology Nuclear Medicine and Imaging                  368
# Name: single_label, dtype: int64

# %%
#sep_subjects.head(n=50)
sep_subjects.shape
#sep_subjects.loc[0,'single_label'] #= 'test'
#np.sum(sep_subjects.iloc[0,:].values == 'Biomolecules')
# Out:
# (13906, 9)

# %%
combined_nonull = df_nonull.join(sep_subjects['single_label'])
combined_nonull
# Out:
#                 id                                      subject_areas  \
# 0       2005.13653           ('Biomolecules', 'Quantitative Methods')
# 1       2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2       2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3       2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 4       2005.13466  ('Social and Information Networks', 'Cryptogra...
# ...            ...                                                ...
# 40379  85066470790  ('Microbiology', 'Immunology', 'Insect Science...
# 40380  85065035348                                ('Drug Discovery',)
# 40381  85073540376  ('Parasitology', 'Microbiology', 'Immunology',...
# 40382  85070056122  ('Microbiology', 'Immunology', 'Insect Science...
# 40383  85064407127         ('Microbiology', 'Microbiology (medical)')
#
#                                                    title  \
# 0      unveiling the molecular mechanism of sars-cov-...
# 1      emotion-robust eeg classification for motor im...
# 2      estimates of the proportion of sars-cov-2 infe...
# 3      a mathematical epidemic model using genetic fi...
# 4      on the detection of disinformation campaign ac...
# ...                                                  ...
# 40379  arterivirus nsp4 antagonizes interferon beta p...
# 40380  architectures and mechanical properties of dru...
# 40381  respiratory syncytial virus nonstructural prot...
# 40382  porcine reproductive and respiratory syndrome ...
# 40383  ifitm genes, variants, and their roles in the ...
#
#                                                 abstract  \
# 0      Currently, there is no effective antiviral dru...
# 1      Developments in Brain Computer Interfaces (BCI...
# 2      In this paper a Bayesian SEIR model is studied...
# 3      A compartmental epidemic model based on geneti...
# 4      Online manipulation of information has become ...
# ...                                                  ...
# 40379  © 2019 American Society for Microbiology. All...
# 40380  © 2019 Bentham Science Publishers.Background:...
# 40381  © 2019 Sedeyn et al. This is an open access a...
# 40382  Copyright © 2019 American Society for Microbi...
# 40383  © 2019 Zhao, Li, Winkler, An and Guo.Interfer...
#
#                           single_label
# 0                 Quantitative Methods
# 1                     Machine Learning
# 2            Populations and Evolution
# 3            Populations and Evolution
# 4      Social and Information Networks
# ...                                ...
# 40379                     Microbiology
# 40380                   Drug Discovery
# 40381                     Microbiology
# 40382                     Microbiology
# 40383                     Microbiology
#
# [13906 rows x 5 columns]

# %%
# REMOVING THE BLANK LABEL ROWS -> SHOULD BE 12810 REMAINING
combined_nonull = combined_nonull.loc[combined_nonull['single_label']!=None]
combined_nonull
# Out:
#                 id                                      subject_areas  \
# 0       2005.13653           ('Biomolecules', 'Quantitative Methods')
# 1       2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2       2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3       2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 4       2005.13466  ('Social and Information Networks', 'Cryptogra...
# ...            ...                                                ...
# 40379  85066470790  ('Microbiology', 'Immunology', 'Insect Science...
# 40380  85065035348                                ('Drug Discovery',)
# 40381  85073540376  ('Parasitology', 'Microbiology', 'Immunology',...
# 40382  85070056122  ('Microbiology', 'Immunology', 'Insect Science...
# 40383  85064407127         ('Microbiology', 'Microbiology (medical)')
#
#                                                    title  \
# 0      unveiling the molecular mechanism of sars-cov-...
# 1      emotion-robust eeg classification for motor im...
# 2      estimates of the proportion of sars-cov-2 infe...
# 3      a mathematical epidemic model using genetic fi...
# 4      on the detection of disinformation campaign ac...
# ...                                                  ...
# 40379  arterivirus nsp4 antagonizes interferon beta p...
# 40380  architectures and mechanical properties of dru...
# 40381  respiratory syncytial virus nonstructural prot...
# 40382  porcine reproductive and respiratory syndrome ...
# 40383  ifitm genes, variants, and their roles in the ...
#
#                                                 abstract  \
# 0      Currently, there is no effective antiviral dru...
# 1      Developments in Brain Computer Interfaces (BCI...
# 2      In this paper a Bayesian SEIR model is studied...
# 3      A compartmental epidemic model based on geneti...
# 4      Online manipulation of information has become ...
# ...                                                  ...
# 40379  © 2019 American Society for Microbiology. All...
# 40380  © 2019 Bentham Science Publishers.Background:...
# 40381  © 2019 Sedeyn et al. This is an open access a...
# 40382  Copyright © 2019 American Society for Microbi...
# 40383  © 2019 Zhao, Li, Winkler, An and Guo.Interfer...
#
#                           single_label
# 0                 Quantitative Methods
# 1                     Machine Learning
# 2            Populations and Evolution
# 3            Populations and Evolution
# 4      Social and Information Networks
# ...                                ...
# 40379                     Microbiology
# 40380                   Drug Discovery
# 40381                     Microbiology
# 40382                     Microbiology
# 40383                     Microbiology
#
# [13906 rows x 5 columns]

# %%
label_counts = pd.DataFrame(combined_nonull['single_label'].value_counts())
label_counts = label_counts.head(n=35)
label_counts
# Out:
#                                                     single_label
# Infectious Diseases                                         1866
# Public Health Environmental and Occupational He...           639
# Surgery                                                      568
# Psychiatry and Mental Health                                 375
# Radiology Nuclear Medicine and Imaging                       368
# Biochemistry Genetics and Molecular Biology all              359
# Cardiology and Cardiovascular Medicine                       332
# Populations and Evolution                                    330
# Immunology                                                   311
# Biochemistry                                                 260
# Pharmacology                                                 220
# Molecular Biology                                            208
# Microbiology                                                 202
# Otorhinolaryngology                                          185
# Education                                                    185
# Pediatrics Perinatology and Child Health                     182
# Geography Planning and Development                           182
# Multidisciplinary                                            174
# Oncology                                                     173
# Virology                                                     168
# Health Policy                                                157
# Pollution                                                    142
# Veterinary all                                               131
# Health Informatics                                           130
# Pharmacology medical                                         129
# Clinical Psychology                                          128
# Neurology                                                    128
# Pulmonary and Respiratory Medicine                           127
# Hematology                                                   125
# Neurology clinical                                           124
# Anesthesiology and Pain Medicine                             119
# Machine Learning                                             117
# Physics and Society                                          116
# Applied Mathematics                                          115
# Endocrinology Diabetes and Metabolism                        112

# %% [markdown]
# Narrowing combined_nonull down into the top 35 classes.

# %%
# New col top_35_label
combined_nonull_35 = combined_nonull
combined_nonull_35['top_35_label'] = ""

for index,row in combined_nonull_35.iterrows(): 
    if combined_nonull_35.loc[index,'single_label'] in label_counts.index.to_list():
        combined_nonull_35.loc[index,'top_35_label'] = combined_nonull_35.loc[index,'single_label']

combined_nonull_35
# Remove all rows with ""  top_35_label
# Out:
#                 id                                      subject_areas  \
# 0       2005.13653           ('Biomolecules', 'Quantitative Methods')
# 1       2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2       2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3       2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 4       2005.13466  ('Social and Information Networks', 'Cryptogra...
# ...            ...                                                ...
# 40379  85066470790  ('Microbiology', 'Immunology', 'Insect Science...
# 40380  85065035348                                ('Drug Discovery',)
# 40381  85073540376  ('Parasitology', 'Microbiology', 'Immunology',...
# 40382  85070056122  ('Microbiology', 'Immunology', 'Insect Science...
# 40383  85064407127         ('Microbiology', 'Microbiology (medical)')
#
#                                                    title  \
# 0      unveiling the molecular mechanism of sars-cov-...
# 1      emotion-robust eeg classification for motor im...
# 2      estimates of the proportion of sars-cov-2 infe...
# 3      a mathematical epidemic model using genetic fi...
# 4      on the detection of disinformation campaign ac...
# ...                                                  ...
# 40379  arterivirus nsp4 antagonizes interferon beta p...
# 40380  architectures and mechanical properties of dru...
# 40381  respiratory syncytial virus nonstructural prot...
# 40382  porcine reproductive and respiratory syndrome ...
# 40383  ifitm genes, variants, and their roles in the ...
#
#                                                 abstract  \
# 0      Currently, there is no effective antiviral dru...
# 1      Developments in Brain Computer Interfaces (BCI...
# 2      In this paper a Bayesian SEIR model is studied...
# 3      A compartmental epidemic model based on geneti...
# 4      Online manipulation of information has become ...
# ...                                                  ...
# 40379  © 2019 American Society for Microbiology. All...
# 40380  © 2019 Bentham Science Publishers.Background:...
# 40381  © 2019 Sedeyn et al. This is an open access a...
# 40382  Copyright © 2019 American Society for Microbi...
# 40383  © 2019 Zhao, Li, Winkler, An and Guo.Interfer...
#
#                           single_label               top_35_label
# 0                 Quantitative Methods
# 1                     Machine Learning           Machine Learning
# 2            Populations and Evolution  Populations and Evolution
# 3            Populations and Evolution  Populations and Evolution
# 4      Social and Information Networks
# ...                                ...                        ...
# 40379                     Microbiology               Microbiology
# 40380                   Drug Discovery
# 40381                     Microbiology               Microbiology
# 40382                     Microbiology               Microbiology
# 40383                     Microbiology               Microbiology
#
# [13906 rows x 6 columns]

# %%
combined_nonull_35 = combined_nonull_35.drop(combined_nonull_35[combined_nonull_35.top_35_label == ""].index)
combined_nonull_35
# Out:
#                 id                                      subject_areas  \
# 1       2005.13523  ('Signal Processing', 'Human-Computer Interact...
# 2       2005.13519  ('Populations and Evolution', 'Physics and Soc...
# 3       2005.13516  ('Populations and Evolution', 'Quantitative Me...
# 8       2005.13285  ('Quantitative Methods', 'Machine Learning', '...
# 9       2005.13282  ('Populations and Evolution', 'Social and Info...
# ...            ...                                                ...
# 40378  85069597990  ('Biochemistry, Genetics and Molecular Biology...
# 40379  85066470790  ('Microbiology', 'Immunology', 'Insect Science...
# 40381  85073540376  ('Parasitology', 'Microbiology', 'Immunology',...
# 40382  85070056122  ('Microbiology', 'Immunology', 'Insect Science...
# 40383  85064407127         ('Microbiology', 'Microbiology (medical)')
#
#                                                    title  \
# 1      emotion-robust eeg classification for motor im...
# 2      estimates of the proportion of sars-cov-2 infe...
# 3      a mathematical epidemic model using genetic fi...
# 8      paccmannrl on sars-cov-2: designing antiviral ...
# 9      simulation of the covid-19 pandemic on the soc...
# ...                                                  ...
# 40378  effectiveness of zinc supplementation on diarr...
# 40379  arterivirus nsp4 antagonizes interferon beta p...
# 40381  respiratory syncytial virus nonstructural prot...
# 40382  porcine reproductive and respiratory syndrome ...
# 40383  ifitm genes, variants, and their roles in the ...
#
#                                                 abstract  \
# 1      Developments in Brain Computer Interfaces (BCI...
# 2      In this paper a Bayesian SEIR model is studied...
# 3      A compartmental epidemic model based on geneti...
# 8      With the fast development of COVID-19 into a g...
# 9      In the article a virus transmission model is c...
# ...                                                  ...
# 40378  © 2019 Feldmann et al. This is an open access...
# 40379  © 2019 American Society for Microbiology. All...
# 40381  © 2019 Sedeyn et al. This is an open access a...
# 40382  Copyright © 2019 American Society for Microbi...
# 40383  © 2019 Zhao, Li, Winkler, An and Guo.Interfer...
#
#                                           single_label  \
# 1                                     Machine Learning
# 2                            Populations and Evolution
# 3                            Populations and Evolution
# 8                                     Machine Learning
# 9                            Populations and Evolution
# ...                                                ...
# 40378  Biochemistry Genetics and Molecular Biology all
# 40379                                     Microbiology
# 40381                                     Microbiology
# 40382                                     Microbiology
# 40383                                     Microbiology
#
#                                           top_35_label
# 1                                     Machine Learning
# 2                            Populations and Evolution
# 3                            Populations and Evolution
# 8                                     Machine Learning
# 9                            Populations and Evolution
# ...                                                ...
# 40378  Biochemistry Genetics and Molecular Biology all
# 40379                                     Microbiology
# 40381                                     Microbiology
# 40382                                     Microbiology
# 40383                                     Microbiology
#
# [9187 rows x 6 columns]

# %%
combined_nonull_35['top_35_label'].value_counts()
# Out:
# Infectious Diseases                                    1866
# Public Health Environmental and Occupational Health     639
# Surgery                                                 568
# Biochemistry Genetics and Molecular Biology all         567
# Psychiatry and Mental Health                            375
# Radiology Nuclear Medicine and Imaging                  368
# Cardiology and Cardiovascular Medicine                  332
# Populations and Evolution                               330
# Immunology                                              311
# Biochemistry                                            260
# Pharmacology                                            220
# Microbiology                                            202
# Otorhinolaryngology                                     185
# Education                                               185
# Geography Planning and Development                      182
# Pediatrics Perinatology and Child Health                182
# Multidisciplinary                                       174
# Oncology                                                173
# Virology                                                168
# Health Policy                                           157
# Pollution                                               142
# Veterinary all                                          131
# Health Informatics                                      130
# Pharmacology medical                                    129
# Clinical Psychology                                     128
# Neurology                                               128
# Pulmonary and Respiratory Medicine                      127
# Hematology                                              125
# Neurology clinical                                      124
# Anesthesiology and Pain Medicine                        119
# Machine Learning                                        117
# Physics and Society                                     116
# Applied Mathematics                                     115
# Endocrinology Diabetes and Metabolism                   112
# Name: top_35_label, dtype: int64

# %%
# Regrouping certain categories
for index,row in combined_nonull_35.iterrows(): 
    if combined_nonull_35.loc[index,'single_label']=="Pharmacology medical":
        combined_nonull_35.loc[index,'top_35_label'] = "Pharmacology"

combined_nonull_35['top_35_label'].value_counts().shape # should be 31 labels left!
# Out:
# (31,)

# %% [markdown]
# Next steps:
# 1. Sort for_export by class label (alpha)
# 2. Loop through each top_35_label index
# 3. Set 'test_limit' to be round(0.8 * count of label)
# Split each class into 80% test, 20% train
# 2.
# 4. Exporting the txt files!
#
# Notes:
# 8608 in the top 30 label classes
# 7976 in the top 25 classes
# 9187 in 31 (some combned from 35) classes

# %%
combined_nonull_35['title_abstract'] = combined_nonull_35['title'] + '. ' + combined_nonull_35['abstract']
#combined_nonull_35.loc[1,'title_abstract']

# %%
# Sorting labels and counts alphabetically
top_35_labels = pd.DataFrame(combined_nonull_35['top_35_label'].value_counts())
top_35_labels = top_35_labels.sort_index()

# %%
# for i in top_35_labels.index:
#     print(math.ceil(top_35_labels.loc[i].values[0]*0.8))
top_35_labels.to_csv('top_35_labels_count.csv')

# %%
# sorting the df alphabetically by label
for_export = combined_nonull_35[['id','title_abstract','top_35_label']]
for_export = for_export.sort_values('top_35_label')

# %%
for_export['test_train'] = ""
for_export.to_csv('id_abstract_label_testtrain.csv')

# %%
# Setting 80% of each class to be train. 
for i in range(len(top_35_labels.index)):
    current_label = top_35_labels.index[i]
    train_limit = math.ceil(top_35_labels.loc[current_label].values[0]*0.8)
    n_train = 0
    temp_df = for_export.loc[for_export['top_35_label']==current_label]
    
    for j in temp_df.index: 
        if n_train < train_limit: 
            for_export.loc[j,'test_train'] = 'train'
            n_train += 1
        else:
            for_export.loc[j,'test_train'] = 'test'

# %%
for_export
# path | test/train | label
# path = 'data/covid_19_production/' + test_train + '/' + id
# Out:
#                 id                                     title_abstract  \
# 17184  85083159584  initial clinical impressions of the critical c...
# 33483  85085700154  the aerosol box for intubation in coronavirus ...
# 21990  85086169697  telemedicine for chronic pain management durin...
# 26905  85084617413  coronavirus disease 2019 (covid-19): two case ...
# 25670  85085755714  re-emergence of tiva in covid times. © 2020 I...
# ...            ...                                                ...
# 18625  85086928118  rapid differentiation of pedv wild-type strain...
# 40167  85077224435  evaluation of serological assays available in ...
# 28598  85082507850  looking after yourself and others. British Vet...
# 39903  85066491992  characterization of antiviral t cell responses...
# 39952  85065181554  ubxn1 interacts with the s1 protein of transmi...
#
#                            top_35_label test_train
# 17184  Anesthesiology and Pain Medicine      train
# 33483  Anesthesiology and Pain Medicine      train
# 21990  Anesthesiology and Pain Medicine      train
# 26905  Anesthesiology and Pain Medicine      train
# 25670  Anesthesiology and Pain Medicine      train
# ...                                 ...        ...
# 18625                    Veterinary all       test
# 40167                    Veterinary all       test
# 28598                    Veterinary all       test
# 39903                    Veterinary all       test
# 39952                    Veterinary all       test
#
# [9187 rows x 4 columns]

# %%
file_details = for_export[['id','test_train','top_35_label']]
file_details
# Out:
#                 id test_train                      top_35_label
# 17184  85083159584      train  Anesthesiology and Pain Medicine
# 33483  85085700154      train  Anesthesiology and Pain Medicine
# 21990  85086169697      train  Anesthesiology and Pain Medicine
# 26905  85084617413      train  Anesthesiology and Pain Medicine
# 25670  85085755714      train  Anesthesiology and Pain Medicine
# ...            ...        ...                               ...
# 18625  85086928118       test                    Veterinary all
# 40167  85077224435       test                    Veterinary all
# 28598  85082507850       test                    Veterinary all
# 39903  85066491992       test                    Veterinary all
# 39952  85065181554       test                    Veterinary all
#
# [9187 rows x 3 columns]

# %%
for i in file_details.index: 
    file_details.loc[i,'path'] = 'data/covid_19_production/' + file_details.loc[i,'test_train'] + '/' + file_details.loc[i,'id']
file_details
# Out:
#                                              path           id test_train  \
# 17184  data/covid_19_production/train/85083159584  85083159584      train
# 33483  data/covid_19_production/train/85085700154  85085700154      train
# 21990  data/covid_19_production/train/85086169697  85086169697      train
# 26905  data/covid_19_production/train/85084617413  85084617413      train
# 25670  data/covid_19_production/train/85085755714  85085755714      train
# ...                                           ...          ...        ...
# 18625   data/covid_19_production/test/85086928118  85086928118       test
# 40167   data/covid_19_production/test/85077224435  85077224435       test
# 28598   data/covid_19_production/test/85082507850  85082507850       test
# 39903   data/covid_19_production/test/85066491992  85066491992       test
# 39952   data/covid_19_production/test/85065181554  85065181554       test
#
#                            top_35_label
# 17184  Anesthesiology and Pain Medicine
# 33483  Anesthesiology and Pain Medicine
# 21990  Anesthesiology and Pain Medicine
# 26905  Anesthesiology and Pain Medicine
# 25670  Anesthesiology and Pain Medicine
# ...                                 ...
# 18625                    Veterinary all
# 40167                    Veterinary all
# 28598                    Veterinary all
# 39903                    Veterinary all
# 39952                    Veterinary all
#
# [9187 rows x 4 columns]

# %%
file_details = file_details[['path','test_train','top_35_label']]
file_details
# Out:
#                                              path test_train  \
# 17184  data/covid_19_production/train/85083159584      train
# 33483  data/covid_19_production/train/85085700154      train
# 21990  data/covid_19_production/train/85086169697      train
# 26905  data/covid_19_production/train/85084617413      train
# 25670  data/covid_19_production/train/85085755714      train
# ...                                           ...        ...
# 18625   data/covid_19_production/test/85086928118       test
# 40167   data/covid_19_production/test/85077224435       test
# 28598   data/covid_19_production/test/85082507850       test
# 39903   data/covid_19_production/test/85066491992       test
# 39952   data/covid_19_production/test/85065181554       test
#
#                            top_35_label
# 17184  Anesthesiology and Pain Medicine
# 33483  Anesthesiology and Pain Medicine
# 21990  Anesthesiology and Pain Medicine
# 26905  Anesthesiology and Pain Medicine
# 25670  Anesthesiology and Pain Medicine
# ...                                 ...
# 18625                    Veterinary all
# 40167                    Veterinary all
# 28598                    Veterinary all
# 39903                    Veterinary all
# 39952                    Veterinary all
#
# [9187 rows x 3 columns]

# %%
file_details.to_csv('covid_19_production.txt',sep='\t',header=False, index=False)

# %%
txt_export = for_export
txt_export
# Out:
#                 id                                     title_abstract  \
# 17184  85083159584  initial clinical impressions of the critical c...
# 33483  85085700154  the aerosol box for intubation in coronavirus ...
# 21990  85086169697  telemedicine for chronic pain management durin...
# 26905  85084617413  coronavirus disease 2019 (covid-19): two case ...
# 25670  85085755714  re-emergence of tiva in covid times. © 2020 I...
# ...            ...                                                ...
# 18625  85086928118  rapid differentiation of pedv wild-type strain...
# 40167  85077224435  evaluation of serological assays available in ...
# 28598  85082507850  looking after yourself and others. British Vet...
# 39903  85066491992  characterization of antiviral t cell responses...
# 39952  85065181554  ubxn1 interacts with the s1 protein of transmi...
#
#                            top_35_label test_train
# 17184  Anesthesiology and Pain Medicine      train
# 33483  Anesthesiology and Pain Medicine      train
# 21990  Anesthesiology and Pain Medicine      train
# 26905  Anesthesiology and Pain Medicine      train
# 25670  Anesthesiology and Pain Medicine      train
# ...                                 ...        ...
# 18625                    Veterinary all       test
# 40167                    Veterinary all       test
# 28598                    Veterinary all       test
# 39903                    Veterinary all       test
# 39952                    Veterinary all       test
#
# [9187 rows x 4 columns]

# %%
for i in txt_export.index: 
    txt_data = txt_export.loc[i,'title_abstract']
    path = txt_export.loc[i,'test_train'] + '/' + txt_export.loc[i,'id'] + '.txt'
    file = open(path,"w")
    file.write(txt_data)
    file.close()
